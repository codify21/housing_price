# %% [markdown]
# # 1.Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#to diplay all the columns of the dataframe in the notebook
# x =pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# # 2.Importing Dataset

# %%
data =pd.read_csv('train.csv')
data.shape
# Out:
# (1460, 81)

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## 3. Analysing Dataset to identify:
# #### 1.Missing Values
# #### 2.Numerical values
# ####  3.Distribution of numerical variables
# #### 4.Outliers
# #### 5.Categorical Variables
# #### 6.Cardinality of categorical variables
# #### 7.Potential relationship b/w variable & target sales price.

# %% [markdown]
# ### 3(a) Missing Values
# Finding out which variables have mssing values

# %%
var_with_na = [ var for var in data.columns if (data[var].isnull().sum())>1]

for var in var_with_na:
    print(var , np.round(data[var].isnull().mean(),3)*100,'%missing values')
# Out:
# LotFrontage 17.7 %missing values
# Alley 93.8 %missing values
# MasVnrType 0.5 %missing values
# MasVnrArea 0.5 %missing values
# BsmtQual 2.5 %missing values
# BsmtCond 2.5 %missing values
# BsmtExposure 2.6 %missing values
# BsmtFinType1 2.5 %missing values
# BsmtFinType2 2.6 %missing values
# FireplaceQu 47.3 %missing values
# GarageType 5.5 %missing values
# GarageYrBlt 5.5 %missing values
# GarageFinish 5.5 %missing values
# GarageQual 5.5 %missing values
# GarageCond 5.5 %missing values
# PoolQC 99.5 %missing values
# Fence 80.80000000000001 %missing values
# MiscFeature 96.3 %missing values

# %% [markdown]
# #### Relationship b/w missing values and sales price

# %%
def analyse_na_value(df,var):
    df = df.copy()
    
    #Making variable that indicates 1 if observation was missing or 0 otherwise
    df[var] = np.where(df[var].isnull(),1,0) 
    
    #calculate the median salesprice where the information is missing or present
    df.groupby(var)['SalePrice'].median().plot.bar()
    plt.title(var)
    plt.show()
    
for var in var_with_na:
    analyse_na_value(data,var)

# %% [markdown]
# ### 3(b) Numerical Variables

# %%
num_vars = [var for var in data.columns if data[var].dtypes != 'O']
len(num_vars)
# Out:
# 38

# %%
data[num_vars].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# ### 3(b)(1) Temporal variables

# %%
year_vars = [var for var in num_vars if 'Yr' in var or 'Year' in var]
year_vars
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for var in year_vars:
    print(var , data[var].unique())
    print()
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
#
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
#
# ...

# %%
data.groupby('YearRemodAdd')['SalePrice'].median().plot()
plt.ylabel('Median House Price')
plt.title('Change in Houseprice with years')
# Out:
# Text(0.5, 1.0, 'Change in Houseprice with years')

# %%
#To analyse b/w house price & year variables in more detail
def analyse_year_vars(df,var):
    df= df.copy()
    
    df[var]= df['YrSold']-df[var]
    
    plt.scatter(df[var],df['SalePrice'])
    plt.ylabel('SalePrice')
    plt.xlabel(var)
    plt.show()
    
for var in year_vars:
    if var != 'YrSold':
        analyse_year_vars(data,var)

# %% [markdown]
#    ### 3(b)(2) : Discrete Variables : shows a finite no. of values

# %%
discrete_vars = [var for var in num_vars if len(data[var].unique())<20 and var not in year_vars+['Id'] ]
print(len(discrete_vars))
discrete_vars
# Out:
# 14
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'PoolArea',
#  'MoSold']

# %%
data[discrete_vars].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0          60            7            5             1             0         2
# 1          20            6            8             0             1         2
# 2          60            7            5             1             0         2
# 3          70            7            5             1             0         1
# 4          60            8            5             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  \
# 0         1             3             1             8           0           2
# 1         0             3             1             6           1           2
# 2         1             3             1             6           1           2
# 3         0             3             1             7           1           3
# 4         1             4             1             9           1           3
#
#    PoolArea  MoSold
# ...

# %% [markdown]
# #### Relationship b/w discrete variables and sales price

# %%
def analyse_discrete(df,var):
    df= df.copy()
    df.groupby(var)['SalePrice'].median().plot.bar()
    plt.title(var)
    plt.ylabel('SalePrice')
    plt.show()
    
for var in discrete_vars:
    analyse_discrete(data,var)

# %% [markdown]
#    ### 3(b)(3) : Continous Variables

# %%
#every other remaining variable except for year & discrete will be considered as continous for now

count_vars = [var for var in num_vars if var not in discrete_vars+year_vars+['Id']]
print(count_vars)
print(len(count_vars))
# Out:
# ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal', 'SalePrice']
# 19

# %%
data[count_vars].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  GarageArea  \
# 0          856       856       854             0       1710         548
# 1         1262      1262         0             0       1262         460
# 2          920       920       866             0       1786         608
# 3          756       961       756             0       1717         642
# 4         1145      1145      1053             0       2198         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  MiscVal  \
# ...

# %% [markdown]
# #### Relationship b/w continous variables and sales price

# %%
def analyse_continous(df,var):
    df= df.copy()
    df[var].hist(bins=20)
    plt.ylabel('No. of houses')
    plt.xlabel(var)
    plt.title(var)
    plt.show()
    
for var in count_vars:
    analyse_continous(data,var)

# %% [markdown]
# ### Applying transformations to convert the skewed distribution into more like gaussion distribution

# %%
def analyse_transformed_continous(df,var):
    df =df.copy()
    
    #log dont take 0 or negative values , so transformation applied to only positive & non-zero variables
    if 0 in df[var].unique():
        pass
    else:
        df[var]=np.log(df[var])
        df[var].hist(bins=20)
        plt.ylabel('Number of Houses')
        plt.xlabel(var)
        plt.title(var)
        plt.show()
for var in count_vars:
    analyse_transformed_continous(data,var)

# %%
#Exploring relationship b/w house price and transformed variables
def transform_analyse_continous(df,var):
    df =df.copy()
    
    if 0 in df[var].unique():
        pass
    else:
        df[var]=np.log(df[var])
        df['SalePrice']= np.log(df['SalePrice'])
        plt.scatter(df[var],df['SalePrice'])
        plt.ylabel('Saleprice')
        plt.xlabel(var)
        plt.show()
        
for var in count_vars:
    if var != 'SalePrice':
        transform_analyse_continous(data,var)

# %% [markdown]
# ### 3(d) Outliers

# %%
#Making boxplots to visualise outliers
def find_outliers(df,var):
    df = df.copy()
    
    if 0 in data[var].unique():
        pass
    else:
        df[var] = np.log(df[var])
        df.boxplot(column = var)
        plt.title(var)
        plt.ylabel(var)
        plt.show()
        
for var in count_vars:
    find_outliers(data,var)

# %% [markdown]
# ### 3(e) Categorical Variables

# %%
cat_vars = [var for var in data.columns if data[var].dtypes =='O']

print('No. of. categorical variables',len(cat_vars))
# Out:
# No. of. categorical variables 43
